# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
civilian_labor_df = pd.read_csv('civilian-labor-force-by-sex.csv')
civilian_labor_df.head()
# Out:
#    Year Number of women in the civilian labor force (in thousands)  \
# 0  1948                                             17,335
# 1  1949                                             17,788
# 2  1950                                             18,389
# 3  1951                                             19,016
# 4  1952                                             19,269
#
#   Number of men in the civilian labor force (in thousands)  \
# 0                                             43,286
# 1                                             43,498
# 2                                             43,819
# 3                                             43,001
# 4                                             42,869
#
#    Share of the civilian labor force who are women (percent)  \
# 0                                               28.6
# 1                                               29.0
# 2                                               29.6
# ...

# %%
x_axis = civilian_labor_df["Year"]
num_women = civilian_labor_df["Number of women in the civilian labor force (in thousands)"]
num_men = civilian_labor_df["Number of men in the civilian labor force (in thousands)"]
percent_women = civilian_labor_df["Share of the civilian labor force who are women (percent)"]
percent_men = civilian_labor_df["Share of the civilian labor force who are men (percent)"]

# %%
plt.rcParams["figure.figsize"] = [20,10]
plt.title("Increasing Percentage of Women by Year", fontsize=20)
plt.xlabel("Year",  fontsize=20)
plt.ylabel("Percent of Women in Workforce", fontsize=20)
#plt.hlines(0, 0, 10, alpha=0.25)
plt.plot(x_axis,percent_women)

# %%
gdp_df = pd.read_csv('US_GDP_by_Quarter.csv')
gdp_df.rename(columns={'DATE_BY_QUARTER':'Date',
                          'BILLIONS_OF_DOLLARS':'Dollars (in Billions)'}, 
                 inplace=True)

gdp_df.head()
# Out:
#          Date  Dollars (in Billions)
# 0  1947-01-01                  243.1
# 1  1947-04-01                  246.3
# 2  1947-07-01                  250.1
# 3  1947-10-01                  260.3
# 4  1948-01-01                  266.2

# %%
gdp_df[["Year", "Month", "Day"]] = gdp_df["Date"].str.split("-", expand=True)
yearly_groupby_df = gdp_df.groupby(["Year"]).mean()
#yearly_groupby_df.head()
yearly_groupby_df_IDX = yearly_groupby_df.reset_index('Year')
#axis2 = yearly_groupby_df['Year']
#Dollars = yearly_groupby_df['Dollars (in Billions)']
#yearly_gdp_mean = yearly_groupby_df.mean()
#yearly_gdp_mean.head()
#x_axis2

# %%
yearly_groupby_df_IDX.head()
# Out:
#    Year  Dollars (in Billions)
# 0  1947                249.950
# 1  1948                274.825
# 2  1949                272.850
# 3  1950                300.175
# 4  1951                347.325

# %%
#plt.plot(x_axis,percent_women)
#yearly_groupby_df.plot()
plt.rcParams["figure.figsize"] = [20,10]
plt.title("Increasing Percentage of Women by Year", fontsize=20)
plt.xlabel("Year",  fontsize=20)
plt.ylabel("Percent of Women in Workforce", fontsize=20)
#plt.hlines(0, 0, 10, alpha=0.25)
plt.plot(x_axis,percent_women)

# %%
yearly_groupby_df_IDX.plot(color='red',grid=True, secondary_y=True)
plt.legend(loc='upper right')
plt.show()

# %%
Df_all_cols = pd.merge(left = civilian_labor_df, right = yearly_groupby_df_IDX,left_on = 'Year', right_on = 'Year')
#print(Df_all_cols)
Df_all_cols.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-55e0eb0faf35> in <module>()
# ----> 1 Df_all_cols = pd.merge(left = civilian_labor_df, right = yearly_groupby_df_IDX,left_on = 'Year', right_on = 'Year')
#       2 #print(Df_all_cols)
#       3 Df_all_cols.head()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ...

# %%
plt.plot(x_axis,percent_women,'Dollars(in Billions)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-53f5d2d1a719> in <module>()
# ----> 1 plt.plot(x_axis,percent_women,'Dollars(in Billions)')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
x_axis_gdp = gdp_df["Year"].unique()
dollars = yearly_gdp_mean["Dollars (in Billions)"]

# %%
plt.plot(x_axis_gdp, dollars)
plt.title("GDP Growth")
plt.xlabel("Years")
plt.ylabel("Dollars (in Billions)")

# important!!! 
# need to use TICK LOCATIONS to change labeling of dates on the x axis of gdp plot
# Out:
# Text(0,0.5,'Dollars (in Billions)')
