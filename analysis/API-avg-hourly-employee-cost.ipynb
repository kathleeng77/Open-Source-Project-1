# %%
import requests
import json

#import prettytable
headers1 = {'Content-type': 'application/json'}
data1 = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"1960", "endyear":"1969"})
p1 = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data1, headers=headers1)
json_data1 = json.loads(p1.text)

headers2 = {'Content-type': 'application/json'}
data2 = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"1970", "endyear":"1979"})
p2 = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data2, headers=headers2)
json_data2 = json.loads(p2.text)

headers3 = {'Content-type': 'application/json'}
data3 = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"1980", "endyear":"1989"})
p3 = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data3, headers=headers3)
json_data3 = json.loads(p3.text)

headers4 = {'Content-type': 'application/json'}
data4 = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"1990", "endyear":"1999"})
p4 = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data4, headers=headers4)
json_data4 = json.loads(p4.text)

headers5 = {'Content-type': 'application/json'}
data5 = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2000", "endyear":"2009"})
p5 = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data5, headers=headers5)
json_data5 = json.loads(p5.text)

headers6 = {'Content-type': 'application/json'}
data6 = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2010", "endyear":"2019"})
p6 = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data6, headers=headers6)
json_data6 = json.loads(p6.text)

# %%
pp.pprint(json_data1)
pp.pprint(json_data2)
pp.pprint(json_data3)
pp.pprint(json_data4)
pp.pprint(json_data5)
pp.pprint(json_data6)
# Out:
# {   'Results': {   'series': [   {   'data': [   {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '37.7',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '37.5',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '37.3',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '37.1',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '37.0',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '36.8',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '36.6',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '36.4',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '36.3',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '36.1',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '35.8',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '35.6',
#                                                      'year': '1969'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '35.5',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '35.4',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '35.3',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '35.1',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '35.0',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '34.9',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '34.7',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '34.5',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '34.4',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '34.3',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '34.2',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '34.1',
#                                                      'year': '1968'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '33.9',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '33.8',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '33.7',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '33.6',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '33.5',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '33.4',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '33.3',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '33.2',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '33.1',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '33.0',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '32.9',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '32.9',
#                                                      'year': '1967'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '32.9',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '32.9',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '32.9',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '32.7',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '32.7',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '32.5',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '32.4',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '32.3',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '32.3',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '32.1',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '32.0',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '31.8',
#                                                      'year': '1966'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '31.8',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '31.7',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '31.7',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '31.6',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '31.6',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '31.6',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '31.6',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '31.4',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '31.4',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '31.3',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '31.2',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '31.2',
#                                                      'year': '1965'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '31.2',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '31.2',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '31.1',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '31.1',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '31.0',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '31.1',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '31.0',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '30.9',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '30.9',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '30.9',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '30.9',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '30.9',
#                                                      'year': '1964'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '30.9',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '30.8',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '30.8',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '30.7',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '30.7',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '30.7',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '30.6',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '30.5',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '30.5',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '30.5',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '30.4',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '30.4',
#                                                      'year': '1963'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '30.4',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '30.4',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '30.4',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '30.4',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '30.3',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '30.3',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '30.2',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '30.2',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '30.2',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '30.1',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '30.1',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '30.0',
#                                                      'year': '1962'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '30.0',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '30.0',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '30.0',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '30.0',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '29.9',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '30.0',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '29.8',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '29.8',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '29.8',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '29.8',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '29.8',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '29.8',
#                                                      'year': '1961'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '29.8',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '29.8',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '29.8',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '29.6',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '29.6',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '29.6',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '29.6',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '29.5',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '29.5',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '29.4',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '29.4',
#                                                      'year': '1960'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '29.3',
#                                                      'year': '1960'}],
#                                      'seriesID': 'CUUR0000SA0'},
#                                  {'data': [], 'seriesID': 'SUUR0000SA0'}]},
#     'message': [   'No Data Available for Series SUUR0000SA0 Year: 1960',
#                    'No Data Available for Series SUUR0000SA0 Year: 1961',
#                    'No Data Available for Series SUUR0000SA0 Year: 1962',
#                    'No Data Available for Series SUUR0000SA0 Year: 1963',
#                    'No Data Available for Series SUUR0000SA0 Year: 1964',
#                    'No Data Available for Series SUUR0000SA0 Year: 1965',
#                    'No Data Available for Series SUUR0000SA0 Year: 1966',
#                    'No Data Available for Series SUUR0000SA0 Year: 1967',
#                    'No Data Available for Series SUUR0000SA0 Year: 1968',
#                    'No Data Available for Series SUUR0000SA0 Year: 1969'],
#     'responseTime': 195,
#     'status': 'REQUEST_SUCCEEDED'}
# {   'Results': {   'series': [   {   'data': [   {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '76.7',
#                                                      'year': '1979'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '75.9',
#                                                      'year': '1979'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '75.2',
#                                                      'year': '1979'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '74.6',
#                                                      'year': '1979'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '73.8',
#                                                      'year': '1979'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '73.1',
#                                                      'year': '1979'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '72.3',
#                                                      'year': '1979'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '71.5',
#                                                      'year': '1979'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '70.6',
#                                                      'year': '1979'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '69.8',
#                                                      'year': '1979'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '69.1',
#                                                      'year': '1979'},
# ...
#                                                      'periodName': 'August',
#                                                      'value': '134.098',
#                                                      'year': '2013'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '133.919',
#                                                      'year': '2013'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '133.900',
#                                                      'year': '2013'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '133.626',
#                                                      'year': '2013'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '133.421',
#                                                      'year': '2013'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '133.558',
#                                                      'year': '2013'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '133.204',
#                                                      'year': '2013'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '132.137',
#                                                      'year': '2013'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '131.770',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '132.208',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '132.892',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '132.988',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '132.430',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '131.731',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '131.956',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '132.154',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '132.284',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '131.905',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '130.953',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '130.438',
#                                                      'year': '2012'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '129.844',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '130.196',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '130.373',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '130.635',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '130.351',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '129.983',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '129.846',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '129.999',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '129.483',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '128.585',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '127.363',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '126.778',
#                                                      'year': '2011'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M12',
#                                                      'periodName': 'December',
#                                                      'value': '126.143',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M11',
#                                                      'periodName': 'November',
#                                                      'value': '125.920',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M10',
#                                                      'periodName': 'October',
#                                                      'value': '125.969',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M09',
#                                                      'periodName': 'September',
#                                                      'value': '125.830',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M08',
#                                                      'periodName': 'August',
#                                                      'value': '125.756',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M07',
#                                                      'periodName': 'July',
#                                                      'value': '125.536',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M06',
#                                                      'periodName': 'June',
#                                                      'value': '125.521',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M05',
#                                                      'periodName': 'May',
#                                                      'value': '125.678',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M04',
#                                                      'periodName': 'April',
#                                                      'value': '125.620',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M03',
#                                                      'periodName': 'March',
#                                                      'value': '125.442',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M02',
#                                                      'periodName': 'February',
#                                                      'value': '124.972',
#                                                      'year': '2010'},
#                                                  {   'footnotes': [{}],
#                                                      'period': 'M01',
#                                                      'periodName': 'January',
#                                                      'value': '124.987',
#                                                      'year': '2010'}],
#                                      'seriesID': 'SUUR0000SA0'}]},
#     'message': [],
#     'responseTime': 200,
#     'status': 'REQUEST_SUCCEEDED'}

# %%
from pprint import pprint
frame1 = [json_data1['Results']['series'][0]['data']]
frame2 = [json_data2['Results']['series'][0]['data']]
frame3 = [json_data3['Results']['series'][0]['data']]
frame4 = [json_data4['Results']['series'][0]['data']]
frame5 = [json_data5['Results']['series'][0]['data']]
frame6 = [json_data6['Results']['series'][0]['data']]

# %%
period = []
month = []
value = []
year = []

for i in range (0,119):
            for info in frame1[0][i]:
                year.append(frame1[0][i]['year'])
                # pprint(frame1[0][i]['year'])
                value.append(frame1[0][i]['value'])
                month.append(frame1[0][i]['periodName'])
                period.append(frame1[0][i]['period'])

# %%
for i in range (0,119):
            for info in frame2[0][i]:
                year.append(frame2[0][i]['year'])
                # pprint(frame2[0][i]['year'])
                value.append(frame2[0][i]['value'])
                month.append(frame2[0][i]['periodName'])
                period.append(frame2[0][i]['period'])

# %%
for i in range (0,119):
            for info in frame3[0][i]:
                year.append(frame3[0][i]['year'])
                # pprint(frame3[0][i]['year'])
                value.append(frame3[0][i]['value'])
                month.append(frame3[0][i]['periodName'])
                period.append(frame3[0][i]['period'])

# %%
for i in range (0,119):
            for info in frame4[0][i]:
                year.append(frame4[0][i]['year'])
                # pprint(frame4[0][i]['year'])
                value.append(frame4[0][i]['value'])
                month.append(frame4[0][i]['periodName'])
                period.append(frame4[0][i]['period'])

# %%
for i in range (0,119):
            for info in frame5[0][i]:
                year.append(frame5[0][i]['year'])
                # pprint(frame5[0][i]['year'])
                value.append(frame5[0][i]['value'])
                month.append(frame5[0][i]['periodName'])
                period.append(frame5[0][i]['period'])

# %%
len(frame6[0])
# Out:
# 113

# %%
for i in range (0,112):
            for info in frame6[0][i]:
                year.append(frame6[0][i]['year'])
                # pprint(frame6[0][i]['year'])
                value.append(frame6[0][i]['value'])
                month.append(frame6[0][i]['periodName'])
                period.append(frame6[0][i]['period'])

# %%
df = pd.DataFrame({"Year": year,
                  "Month": month,
                  "Value": value,
                  "Period": period})
df.head()
# Out:
#    Year     Month Value Period
# 0  1969  December  37.7    M12
# 1  1969  December  37.7    M12
# 2  1969  December  37.7    M12
# 3  1969  December  37.7    M12
# 4  1969  December  37.7    M12

# %%
df.to_csv("data/avg-hourly-employee-cost.csv", encoding='utf-8', index=False)
