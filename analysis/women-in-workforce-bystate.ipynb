# %%
# dependencies and setup
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
state_df = pd.read_csv('../data/workforce-by-state-2018.csv')
state_df
# Out:
#           State                     Population group  \
# 0       Alabama                                Total
# 1       Alabama                                  Men
# 2       Alabama                                Women
# 3       Alabama                                White
# 4       Alabama                           White, men
# 5       Alabama                         White, women
# 6       Alabama            Black or African American
# 7       Alabama       Black or African American, men
# 8       Alabama     Black or African American, women
# 9       Alabama         Hispanic or Latino ethnicity
# 10      Alabama    Hispanic or Latino ethnicity, men
# 11      Alabama                Total, 16 to 19 years
# 12      Alabama                Total, 20 to 24 years
# 13      Alabama                Total, 25 to 34 years
# 14      Alabama                Total, 35 to 44 years
# 15      Alabama                Total, 45 to 54 years
# 16      Alabama                Total, 55 to 64 years
# 17      Alabama             Total, 65 years and over
# 18      Alabama                  Men, 20 to 24 years
# 19      Alabama                  Men, 25 to 34 years
# 20      Alabama                  Men, 35 to 44 years
# 21      Alabama                  Men, 45 to 54 years
# 22      Alabama                  Men, 55 to 64 years
# 23      Alabama               Men, 65 years and over
# 24      Alabama                Women, 20 to 24 years
# 25      Alabama                Women, 25 to 34 years
# 26      Alabama                Women, 35 to 44 years
# 27      Alabama                Women, 45 to 54 years
# 28      Alabama                Women, 55 to 64 years
# 29      Alabama             Women, 65 years and over
# ...         ...                                  ...
# 1394  Wisconsin                Women, 35 to 44 years
# 1395  Wisconsin                Women, 45 to 54 years
# 1396  Wisconsin                Women, 55 to 64 years
# 1397    Wyoming                                Total
# 1398    Wyoming                                  Men
# 1399    Wyoming                                Women
# 1400    Wyoming                                White
# 1401    Wyoming                           White, men
# 1402    Wyoming                         White, women
# 1403    Wyoming         Hispanic or Latino ethnicity
# 1404    Wyoming    Hispanic or Latino ethnicity, men
# 1405    Wyoming  Hispanic or Latino ethnicity, women
# 1406    Wyoming                Total, 16 to 19 years
# 1407    Wyoming                Total, 20 to 24 years
# 1408    Wyoming                Total, 25 to 34 years
# 1409    Wyoming                Total, 35 to 44 years
# 1410    Wyoming                Total, 45 to 54 years
# 1411    Wyoming                Total, 55 to 64 years
# 1412    Wyoming             Total, 65 years and over
# 1413    Wyoming                  Men, 20 to 24 years
# 1414    Wyoming                  Men, 25 to 34 years
# 1415    Wyoming                  Men, 35 to 44 years
# 1416    Wyoming                  Men, 45 to 54 years
# 1417    Wyoming                  Men, 55 to 64 years
# 1418    Wyoming               Men, 65 years and over
# 1419    Wyoming                Women, 20 to 24 years
# 1420    Wyoming                Women, 25 to 34 years
# 1421    Wyoming                Women, 35 to 44 years
# 1422    Wyoming                Women, 45 to 54 years
# 1423    Wyoming                Women, 55 to 64 years
#
#      Civilian non-institutional population  Total  Percent of population  \
# 0                                    3,847  2,208                   57.4
# 1                                    1,820  1,180                   64.9
# 2                                    2,027  1,027                   50.7
# 3                                    2,711  1,567                   57.8
# 4                                    1,310    880                   67.2
# 5                                    1,401    686                   49.0
# 6                                      999    558                   55.8
# 7                                      443    254                   57.4
# 8                                      556    304                   54.6
# 9                                      143     97                   67.5
# 10                                      75     66                   87.4
# 11                                     236     75                   31.9
# 12                                     333    228                   68.5
# 13                                     627    492                   78.5
# 14                                     578    451                   78.0
# 15                                     653    481                   73.7
# 16                                     666    353                   53.0
# 17                                     753    127                   16.9
# 18                                     166    122                   73.2
# 19                                     303    258                   85.1
# 20                                     280    238                   85.0
# 21                                     313    255                   81.4
# 22                                     316    200                   63.4
# 23                                     331     68                   20.4
# 24                                     167    107                   63.8
# 25                                     324    234                   72.3
# 26                                     298    213                   71.5
# 27                                     341    227                   66.6
# 28                                     351    153                   43.7
# 29                                     423     60                   14.1
# ...                                    ...    ...                    ...
# 1394                                   364    314                   86.3
# 1395                                   374    311                   83.1
# 1396                                   416    270                   65.1
# 1397                                   445    287                   64.7
# 1398                                   224    158                   70.4
# 1399                                   221    130                   58.8
# 1400                                   416    268                   64.5
# 1401                                   210    148                   70.5
# 1402                                   206    120                   58.4
# 1403                                    39     26                   67.1
# 1404                                    19     14                   74.3
# 1405                                    20     12                   60.3
# 1406                                    31     15                   48.0
# 1407                                    33     25                   77.0
# 1408                                    78     63                   81.3
# 1409                                    68     60                   89.5
# 1410                                    62     52                   83.5
# 1411                                    78     50                   64.5
# 1412                                    96     22                   22.7
# 1413                                    17     14                   81.1
# 1414                                    38     35                   91.9
# 1415                                    34     32                   94.9
# 1416                                    32     29                   90.8
# 1417                                    36     26                   70.8
# 1418                                    48     13                   27.1
# 1419                                    16     12                   72.0
# 1420                                    39     28                   71.1
# 1421                                    34     28                   84.2
# 1422                                    30     23                   75.5
# 1423                                    42     25                   59.0
#
#      Total Employed  Percent of population Employed Total Unemployed  \
# 0             2,121                            55.1               87
# 1             1,135                            62.4               45
# 2               986                            48.6               42
# 3             1,523                            56.2               44
# 4               857                            65.4               23
# 5               666                            47.5               21
# 6               519                            52.0               38
# 7               235                            53.1               19
# 8               284                            51.1               19
# 9                92                            64.4                5
# 10               64                            85.1                2
# 11               66                            27.9                9
# 12              212                            63.8               16
# 13              469                            74.8               23
# 14              433                            75.0               18
# 15              471                            72.0               11
# 16              347                            52.1                6
# 17              123                            16.3                5
# 18              113                            68.3                8
# 19              248                            81.7               10
# 20              229                            81.6                9
# 21              250                            79.9                5
# 22              196                            61.9                4
# 23               66                            19.8                2
# 24               99                            59.4                7
# 25              222                            68.3               13
# 26              205                            68.7                8
# 27              221                            64.8                6
# 28              152                            43.3                2
# 29               57                            13.5                3
# ...             ...                             ...              ...
# 1394            311                            85.2                4
# 1395            303                            80.9                8
# 1396            265                            63.7                6
# 1397            275                            62.0               12
# 1398            151                            67.5                6
# 1399            124                            56.3                6
# 1400            258                            62.1               10
# 1401            143                            68.1                5
# 1402            115                            56.0                5
# 1403             25                            63.1                2
# 1404             13                            69.7                1
# 1405             11                            57.0                1
# 1406             13                            42.5                2
# 1407             24                            71.8                2
# 1408             60                            77.5                3
# 1409             59                            87.4                1
# 1410             50                            80.1                2
# 1411             49                            62.8                1
# 1412             21                            21.6                1
# 1413             13                            75.9                1
# 1414             33                            87.4                2
# 1415             32                            92.9                1
# 1416             29                            88.0                1
# 1417             25                            68.9                1
# 1418             13                            25.8                1
# 1419             11                            67.5                1
# 1420             27                            67.9                1
# 1421             28                            81.8                1
# 1422             21                            71.6                1
# 1423             24                            57.6                1
#
#       Rate Unemployed
# 0                 3.9
# 1                 3.8
# 2                 4.1
# 3                 2.8
# 4                 2.6
# 5                 3.0
# 6                 6.9
# 7                 7.4
# 8                 6.4
# 9                 4.6
# 10                2.6
# 11               12.5
# 12                6.8
# 13                4.7
# 14                3.9
# 15                2.2
# 16                1.7
# 17                3.6
# 18                6.7
# 19                4.0
# 20                3.9
# 21                1.9
# 22                2.2
# 23                3.1
# 24                7.0
# 25                5.4
# 26                3.9
# 27                2.6
# 28                1.0
# 29                4.2
# ...               ...
# 1394              1.2
# 1395              2.6
# 1396              2.1
# 1397              4.2
# 1398              4.0
# 1399              4.3
# 1400              3.8
# 1401              3.5
# 1402              4.1
# 1403              5.9
# 1404              6.1
# 1405              5.5
# 1406             11.2
# 1407              6.7
# 1408              4.6
# 1409              2.3
# 1410              4.2
# 1411              2.4
# 1412              4.6
# 1413              6.7
# 1414              4.6
# 1415              2.0
# 1416              3.3
# 1417              2.8
# 1418              4.3
# 1419              6.8
# 1420              4.5
# 1421              2.7
# 1422              5.3
# 1423              2.2
#
# [1424 rows x 9 columns]

# %%
# find unique state names
unique_states = state_df["State"].unique()
unique_states
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
state_df["Percent of population Employed"][2]
# Out:
# 48.6

# %%
# groupby population group
women_employed = state_df.groupby(["Population group", "State"])

# %%
women_employed.mean().head()
# Out:
#                                        Percent of population  \
# Population group          State
# Black or African American Alabama                       55.8
#                           Arizona                       72.1
#                           Arkansas                      57.9
#                           California                    61.5
#                           Connecticut                   64.5
#
#                                        Percent of population Employed  \
# Population group          State
# Black or African American Alabama                                52.0
#                           Arizona                                66.0
#                           Arkansas                               54.0
#                           California                             57.5
#                           Connecticut                            58.8
#
#                                        Rate Unemployed
# Population group          State
# Black or African American Alabama                  6.9
#                           Arizona                  8.4
#                           Arkansas                 6.7
#                           California               6.5
#                           Connecticut              8.9

# %%
AL_pop = state_df.loc[state_df['State'] == 'Alabama', 'Population group']
AL_employed = state_df.loc[state_df['State'] == 'Alabama', 'Percent of population Employed']
AL_unemployed = state_df.loc[state_df['State'] == 'Alabama', 'Rate Unemployed']

AL_df = pd.DataFrame({"Population Group": AL_pop,
                    "Percent Employed": AL_employed,
                    "Rate Unemployed": AL_unemployed})
AL_women = AL_df.loc[AL_df["Population Group"] == "Women", "Percent Employed"]
AL_women
# Out:
# 2    48.6
# Name: Percent Employed, dtype: float64

# %%
AK_pop = state_df.loc[state_df['State'] == 'Alaska', 'Population group']
AK_employed = state_df.loc[state_df['State'] == 'Alaska', 'Percent of population Employed']
AK_unemployed = state_df.loc[state_df['State'] == 'Alaska', 'Rate Unemployed']

AK_df = pd.DataFrame({"Population Group": AK_pop,
                    "Percent Employed": AK_employed,
                    "Rate Unemployed": AK_unemployed})
AK_women = AK_df.loc[AK_df["Population Group"] == "Women", "Percent Employed"]
AK_women
# Out:
# 32    58.2
# Name: Percent Employed, dtype: float64

# %%
CA_pop = state_df.loc[state_df['State'] == 'California', 'Population group']
CA_employed = state_df.loc[state_df['State'] == 'California', 'Percent of population Employed']
CA_unemployed = state_df.loc[state_df['State'] == 'California', 'Rate Unemployed']

CA_df = pd.DataFrame({"Population Group": CA_pop,
                    "Percent Employed": CA_employed,
                    "Rate Unemployed": CA_unemployed})
CA_women = CA_df.loc[CA_df["Population Group"] == "Women", "Percent Employed"]
CA_women
# Out:
# 116    52.9
# Name: Percent Employed, dtype: float64

# %%
NY_pop = state_df.loc[state_df['State'] == 'New York', 'Population group']
NY_employed = state_df.loc[state_df['State'] == 'New York', 'Percent of population Employed']
NY_unemployed = state_df.loc[state_df['State'] == 'New York', 'Rate Unemployed']

NY_df = pd.DataFrame({"Population Group": NY_pop,
                    "Percent Employed": NY_employed,
                    "Rate Unemployed": NY_unemployed})
NY_women = NY_df.loc[NY_df["Population Group"] == "Women", "Percent Employed"]
NY_women
# Out:
# 897    53.6
# Name: Percent Employed, dtype: float64
